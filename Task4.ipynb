# %%
#Task 2: Simple Text Classification
def gender_features(word):
    return{
        'last_letter': word[-1]
    }

# %%
gender_features("Obama")
# Out:
# {'last_letter': 'a'}

# %%
from nltk.corpus import names
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-498dafc3f2a1> in <module>
# ----> 1 from nltk.corpus import names
#
# ModuleNotFoundError: No module named 'nltk'

# %%
names.words()
print(len(names.words()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-de9d3f9f2d31> in <module>
# ----> 1 names.words()
#       2 print(len(names.words()))
#
# NameError: name 'names' is not defined

# %%
import random
labelled_names = ([(name,'male') for name in names.words('male.txt')] + [(name,'female') for name in names.words('female.txt')])
random.shuffle(labelled_names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ad2abef13f49> in <module>
#       1 import random
# ----> 2 labelled_names = ([(name,'male') for name in names.words('male.txt')] + [(name,'female') for name in names.words('female.txt')])
#       3 random.shuffle(labelled_names)
#       4
#
# NameError: name 'names' is not defined

# %%
import nltk
featuresets = [(gender_features(n),gender) for (n,gender) in labelled_names]
train_set, test_set = featuresets[:5000],featuresets[5000:]
classifier = nltk.NaiveBayesClassifier.train(train_set)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-3d8ad050edf6> in <module>
# ----> 1 import nltk
#       2 featuresets = [(gender_features(n),gender) for (n,gender) in labelled_names]
#       3 train_set, test_set = featuresets[:5000],featuresets[5000:]
#       4 classifier = nltk.NaiveBayesClassifier.train(train_set)
#
# ModuleNotFoundError: No module named 'nltk'

# %%
classifier.classify(gender_features('Krati'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-21a580ac91fb> in <module>
# ----> 1 classifier.classify(gender_features('Krati'))
#
# NameError: name 'classifier' is not defined

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ee1353d56882> in <module>
# ----> 1 print(nltk.classify.accuracy(classifier, test_set))
#
# NameError: name 'nltk' is not defined

# %%
# Task3: Count Vectorizer
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer(binary=True)
corpus = ["Tessaract is good optical character recognition engine  ", "optical character recognition is significant "]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-eb9572160866> in <module>
#       1 # Task3: Count Vectorizer
# ----> 2 from sklearn.feature_extraction.text import CountVectorizer
#       3 vect = CountVectorizer(binary=True)
#       4 corpus = ["Tessaract is good optical character recognition engine  ", "optical character recognition is significant "]
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
vect.fit(corpus)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-82ef4c1a1c7d> in <module>
# ----> 1 vect.fit(corpus)
#
# NameError: name 'vect' is not defined

# %%
vocab = vect.vocabulary_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-9851b35e8b24> in <module>
# ----> 1 vocab = vect.vocabulary_
#
# NameError: name 'vect' is not defined

# %%
for key in sorted(vocab.keys()):
    print("{}:{}".format(key,vocab[key]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-9142995c4334> in <module>
# ----> 1 for key in sorted(vocab.keys()):
#       2     print("{}:{}".format(key,vocab[key]))
#
# NameError: name 'vocab' is not defined

# %%
print(vect.transform(["This is a good optical illusion"]).toarray())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-71be204fc25a> in <module>
# ----> 1 print(vect.transform(["This is a good optical illusion"]).toarray())
#
# NameError: name 'vect' is not defined

# %%
# Finding similarity between documents
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vect.transform(["Google Cloud Vision is a character recognition engine"]).toarray(), 
                               vect.transform(["OCR is an optical character recognition engine"]).toarray())
print (similarity)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-f68c9e23f929> in <module>
#       1 # Finding similarity between documents
# ----> 2 from sklearn.metrics.pairwise import cosine_similarity
#       3 similarity = cosine_similarity(vect.transform(["Google Cloud Vision is a character recognition engine"]).toarray(),
#       4                                vect.transform(["OCR is an optical character recognition engine"]).toarray())
#       5 print (similarity)
#
# ModuleNotFoundError: No module named 'sklearn'
