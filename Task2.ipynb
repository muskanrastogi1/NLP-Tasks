# %%
# HOMEWORK
# Determine frequency dist  and CFD of any one presidentual inaugural  address
import nltk
from nltk.probability import ConditionalFreqDist
from nltk.corpus import inaugural

# %%
text = inaugural.words(fileids='2005-Bush.txt')[:50]
fd= nltk.FreqDist(text)
fd
# Out:
# FreqDist({',': 10, 'President': 4, 'the': 2, 'by': 2, 'Vice': 1, 'Cheney': 1, 'Mr': 1, '.': 1, 'Chief': 1, 'Justice': 1, ...})

# %%
cfd= ConditionalFreqDist((len(word),word) for word in text)
cfd[5]
# Out:
# FreqDist({'Chief': 1})

# %%
#WordCloud
import matplotlib.pyplot as plt
from nltk.corpus import brown
from wordcloud import WordCloud
 
wc = WordCloud().generate(' '.join(brown.words()))
 
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#Lexicon -> collection of words/Phrases + Information (POS; tense Definitions..)
#Lexicon has lexical entries -> each entry is Word/Phrase -> has a HeadWord(Lemma) + information
#1. Stopwords
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
#2. CMU Wordlist
import nltk
entries = nltk.corpus.cmudict.entries()
len(entries)
# Out:
# 133737

# %%
for i in entries:
    print(i)
# Out:
# ', 'ER0', 'M', 'EH1', 'N', 'OW0'])
# ('zern', ['Z', 'IH1', 'R', 'N'])
# ('zero', ['Z', 'IH1', 'R', 'OW0'])
# ('zero', ['Z', 'IY1', 'R', 'OW0'])
# ('zeroed', ['Z', 'IH1', 'R', 'OW0', 'D'])
# ('zeroed', ['Z', 'IY1', 'R', 'OW0', 'D'])
# ('zeroes', ['Z', 'IH1', 'R', 'OW0', 'Z'])
# ('zeroes', ['Z', 'IY1', 'R', 'OW0', 'Z'])
# ('zeroing', ['Z', 'IY1', 'R', 'OW0', 'IH0', 'NG'])
# ('zeroli', ['Z', 'AH0', 'R', 'OW1', 'L', 'IY0'])
# ("zero's", ['Z', 'IH1', 'R', 'OW0', 'Z'])
# ('zeros', ['Z', 'IH1', 'R', 'OW0', 'Z'])
# ("zero's", ['Z', 'IY1', 'R', 'OW0', 'Z'])
# ('zerr', ['Z', 'IH1', 'R'])
# ('zertuche', ['Z', 'IH1', 'R', 'T', 'AH0', 'K'])
# ('zervas', ['Z', 'IH1', 'R', 'V', 'AH0', 'Z'])
# ('zervos', ['Z', 'IH1', 'R', 'V', 'OW0', 'Z'])
# ('zervos', ['Z', 'ER1', 'V', 'OW0', 'S'])
# ('zerwhale', ['Z', 'ER1', 'W', 'EY2', 'L'])
# ('zest', ['Z', 'EH1', 'S', 'T'])
# ('zestful', ['Z', 'EH1', 'S', 'T', 'F', 'AH0', 'L'])
# ('zeta', ['Z', 'EY1', 'T', 'AH0'])
# ('zettel', ['Z', 'EH1', 'T', 'AH0', 'L'])
# ...

# %%
#3. Wordnet
from nltk.corpus import wordnet as wn
wn.synsets('good')
# Out:
# [Synset('good.n.01'),
#  Synset('good.n.02'),
#  Synset('good.n.03'),
#  Synset('commodity.n.01'),
#  Synset('good.a.01'),
#  Synset('full.s.06'),
#  Synset('good.a.03'),
#  Synset('estimable.s.02'),
#  Synset('beneficial.s.01'),
#  Synset('good.s.06'),
#  Synset('good.s.07'),
#  Synset('adept.s.01'),
#  Synset('good.s.09'),
#  Synset('dear.s.02'),
#  Synset('dependable.s.04'),
#  Synset('good.s.12'),
#  Synset('good.s.13'),
#  Synset('effective.s.04'),
#  Synset('good.s.15'),
#  Synset('good.s.16'),
#  Synset('good.s.17'),
#  Synset('good.s.18'),
#  Synset('good.s.19'),
#  Synset('good.s.20'),
#  Synset('good.s.21'),
#  Synset('well.r.01'),
#  Synset('thoroughly.r.02')]

# %%
wn.synset('thoroughly.r.02').lemma_names()
# Out:
# ['thoroughly', 'soundly', 'good']

# %%
#Stemming
from nltk.stem import PorterStemmer
sp = PorterStemmer()
sp.stem('happiness')
# Out:
# 'happi'

# %%
from nltk.stem import LancasterStemmer
sl = LancasterStemmer()
sl.stem('happy')
# Out:
# 'happy'

# %%
from nltk.stem import SnowballStemmer
SnowballStemmer.languages
fs = SnowballStemmer('french')
fs.stem('manges')
# Out:
# 'mang'

# %%
#Stemming Paragraphs
from nltk.stem import PorterStemmer
sp = PorterStemmer()
text = "Muskan is the best"
text = [sp.stem(token) for token in text.split(" ")]
print(" ".join(text))
# Out:
# muskan is the best

# %%
#Lemmatizer
from nltk.stem import WordNetLemmatizer
lm = WordNetLemmatizer()
lm.lemmatize('nuclei')
# Out:
# 'nucleus'

# %%
lm.lemmatize('cacti')
# Out:
# 'cactus'

# %%
lm.lemmatize('better', pos ='a') #a= adjective
# Out:
# 'good'

# %%
lm.lemmatize('am', pos = 'v') #v= verb
# Out:
# 'be'

# %%
# !pip install jieba

# %%
#Chinese Segmentation using jieba
import jieba
seg = jieba.cut('把句子中所有的可以成词的词语都扫描出来', cut_all = True)
' '.join(seg)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\MUSKAN~1\AppData\Local\Temp\jieba.cache
# Loading model cost 1.540 seconds.
# Prefix dict has been built successfully.
# '把 句子 中所 所有 的 可以 成 词 的 词语 都 扫描 描出 描出来 出来'
