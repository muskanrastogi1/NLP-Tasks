# %%
# TASK 1: BASIC TEXT PROCESSING PIPELINE
import nltk
text1 = '''The Rodrigues rail (Erythromachus leguati) was a flightless 
bird endemic to the Mascarene island of Rodrigues, east of Madagascar 
in the Indian Ocean. The rail was described as having grey plumage, a 
red beak and legs, and a naked red patch around the eye. The bird fed 
on tortoise eggs. It was described as being attracted to red objects, 
which humans exploited while hunting it. The Rodrigues rail is believed 
to have become extinct in the mid-18th century because of predation by 
introduced cats and destruction of its habitat by tortoise hunters. The 
bird was first documented from life by two contemporaneous accounts, first 
by François Leguat, a French Huguenot refugee marooned on Rodrigues in 1691, 
and then by Julien Tafforet, marooned on the island in 1726. Subfossil remains 
(pictured) were later discovered and connected with the old accounts in 1874, 
and the species was named E. leguati in Leguat's honour. '''

for text in text1:
    sentences = nltk.sent_tokenize(text1)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        tagged = nltk.pos_tag(words)
        print(tagged)
# Out:
# [('The', 'DT'), ('Rodrigues', 'NNP'), ('rail', 'NN'), ('(', '('), ('Erythromachus', 'NNP'), ('leguati', 'RB'), (')', ')'), ('was', 'VBD'), ('a', 'DT'), ('flightless', 'JJ'), ('bird', 'NN'), ('endemic', 'NN'), ('to', 'TO'), ('the', 'DT'), ('Mascarene', 'NNP'), ('island', 'NN'), ('of', 'IN'), ('Rodrigues', 'NNP'), (',', ','), ('east', 'NN'), ('of', 'IN'), ('Madagascar', 'NNP'), ('in', 'IN'), ('the', 'DT'), ('Indian', 'JJ'), ('Ocean', 'NNP'), ('.', '.')]
# [('The', 'DT'), ('rail', 'NN'), ('was', 'VBD'), ('described', 'VBN'), ('as', 'IN'), ('having', 'VBG'), ('grey', 'JJ'), ('plumage', 'NN'), (',', ','), ('a', 'DT'), ('red', 'JJ'), ('beak', 'NN'), ('and', 'CC'), ('legs', 'NN'), (',', ','), ('and', 'CC'), ('a', 'DT'), ('naked', 'JJ'), ('red', 'JJ'), ('patch', 'NN'), ('around', 'IN'), ('the', 'DT'), ('eye', 'NN'), ('.', '.')]
# [('The', 'DT'), ('bird', 'NN'), ('fed', 'VBN'), ('on', 'IN'), ('tortoise', 'NN'), ('eggs', 'NNS'), ('.', '.')]
# ...

# %%
# TASK 2: TweetTokenizer
from nltk.tokenize import TweetTokenizer
text = 'Coolest picture we have seen :D #throwbackthursday'
twtk = TweetTokenizer()
twtk.tokenize(text)
# Out:
# ['Coolest', 'picture', 'we', 'have', 'seen', ':D', '#throwbackthursday']

# %%
# TASK 3: Scraping data from Web
from urllib import request
url = "http://www.gutenberg.org/files/2554/2554-0.txt"
response = request.urlopen(url)
raw = response.read().decode('utf8')
type(raw)
len(raw)
raw[:75]
from nltk.tokenize import word_tokenize
tokens = word_tokenize(raw)
type(tokens)
#HTML => ASCII => TEXT => VOCAB
# Out:
# list

# %%
#TASK 4: Handling Tweets Data
import nltk
f = open("/Users/Muskan Rastogi/Downloads/tweets1.txt","r")
text = f.read()
text1 = text.split()
text2 = nltk.Text(text1)
text2.concordance("good")
# Out:
# Displaying 17 of 17 matches:
# n The Signal premiere. Lotsa buyers. Good luck gang listening to the pocast ne
# so going to enjoy this shower. Feels good to have worked on a trail three time
# ose not my friend. it was not a very good day so I have a lot to do tomorrow..
# Oh why cheesecake why? You looked so good evil cake. Now metamucil. Reading: "
# utiful day so Im thinking to spend a good part of it outdoors.first stop at St
# g and ignoring my reaction to a very good friend getting fired. it's like a bi
# d HDH - url wrist sprain= damn pain. good thing it's not on my left hand. Bein
#  I bet I can throw farther than her. Good luck with that dude. Sure it will al
#  Choppers. first day of eid .. feels good Looking to buy a game called Shut th
# g. back from the ASLA 6 Congress. :) Good job ASLA CORE! I'm gonna need to ste
# tching the CNBC video of David Lear. Good job Sean! and now... off to Belize!
# ...
